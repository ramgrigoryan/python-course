# %%
from PIL import Image

# %%
mac = Image.open('images/example.jpg')

# %%
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257 at 0x7F3541FD1060>

# %%
mac.show()

# %%
mac.size
# Out:
# (1993, 1257)

# %%
mac.filename
# Out:
# 'images/example.jpg'

# %%
mac.format_description
# Out:
# 'JPEG (ISO 10918)'

# %% [markdown]
# ### Crop

# %%
mac.crop((800,840,1200,1257))
# Out:
# <PIL.Image.Image image mode=RGB size=400x417 at 0x7F35497A41F0>

# %%
computer = mac.crop((800,840,1200,1257))

# %%
mac.paste(computer,(0,0))

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257 at 0x7F3541FD1060>

# %%
red = Image.open('images/red_color.jpg')

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x7F3541FD3550>

# %%
blue = Image.open('images/blue_color.png')

# %%
blue.size
# Out:
# (200, 200)

# %%
blue.putalpha(200)
